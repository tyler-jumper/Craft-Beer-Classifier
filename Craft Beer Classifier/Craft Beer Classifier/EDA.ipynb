# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
beers = pd.read_csv('beers.csv')

# %%
beers['style'].value_counts()
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Grisette                            1
# Flanders Red Ale                    1
# Smoked Beer                         1
# American Malt Liquor                1
# Braggot                             1
# Name: style, Length: 99, dtype: int64

# %%
df = beers[['ibu','abv']]

# %%
df.corr()
# Out:
#           ibu       abv
# ibu  1.000000  0.670621
# abv  0.670621  1.000000

# %%
beers_IPA = beers[beers['style']=='American IPA']

# %%
beers_APA = beers[beers['style']=='American Pale Ale (APA)']

# %%
beers_sour = beers[beers['style']=='Cider']

# %%
beers_cider.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-59a67fd67004> in <module>
# ----> 1 beers_cider.head()
#
# NameError: name 'beers_cider' is not defined

# %%
beers_APA.head()

# %%
beers_IPA.head()

# %% [raw]
# beers

# %%
beers_IPA[['ibu','abv']].corr()

# %%
beers2 = beers['beers.head(1000)']

# %%
beers2.head()

# %%
sns.scatterplot(x='abv',y='ibu',data=beers_IPA)

# %%
sns.distplot(beers_IPA['abv'],bins = 15)

# %%
sns.distplot(beers_APA['abv'],bins = 15)

# %%
sns.distplot(beers_cider['abv'],bins=10)

# %%
beers[['ibu','abv']].corr()

# %%
beers.head()

# %%
beers.info

# %%
beers['abv'].hist()

# %%
beers.plot.scatter(x='abv',y='ibu')

# %%
sns.countplot(x='style',data=beers)

# %%
beers['ibu'].value_counts()

# %%
style_beer = beers['style'].value_counts().head(10)

# %%
sns.countplot(beers['ibu'])

# %%
beers.groupby('style').mean()['ibu']

# %%
test_beer = beers[(beers['abv']>0.045) & (beers['abv']<.055)]

# %%
test_beer['style'].value_counts()

# %%
beers[beers['style']=='Gose']

# %%
#creating a new data frame of relevant beers
rlvnt_beers = beers['style'].value_counts().to_frame()

# %%
#these beers are beers that have more than 25 examples each
#this mislabeled column 'style' is actually the value count of the particular style of beer
rlvnt_beers.head(20)

# %%
#right now what I'm thinking about doing is making sub datasets of abv and ibu 
#and getting value counts of each style to see if i can see a pattern
beers.describe()
# Out:
#         Unnamed: 0          abv          ibu           id   brewery_id  \
# count  2410.000000  2348.000000  1405.000000  2410.000000  2410.000000
# mean   1204.500000     0.059773    42.713167  1431.113278   231.749793
# std     695.851397     0.013542    25.954066   752.459975   157.685604
# min       0.000000     0.001000     4.000000     1.000000     0.000000
# 25%     602.250000     0.050000    21.000000   808.250000    93.000000
# 50%    1204.500000     0.056000    35.000000  1453.500000   205.000000
# 75%    1806.750000     0.067000    64.000000  2075.750000   366.000000
# max    2409.000000     0.128000   138.000000  2692.000000   557.000000
#
#             ounces
# count  2410.000000
# mean     13.592241
# std       2.352204
# min       8.400000
# 25%      12.000000
# 50%      12.000000
# 75%      16.000000
# max      32.000000

# %%
low_ibu = beers[beers['ibu']<=21]

# %%
high = beers[beers['ibu']>50]

# %%
high = high['style'].value_counts().to_frame().head(20)
high
# Out:
#                                      style
# American IPA                           253
# American Double / Imperial IPA          74
# American Pale Ale (APA)                 43
# American Black Ale                      17
# American Amber / Red Ale                13
# American Strong Ale                     10
# Russian Imperial Stout                   8
# Rye Beer                                 5
# American Porter                          4
# American Stout                           4
# English Barleywine                       3
# American Brown Ale                       3
# Extra Special / Strong Bitter (ESB)      3
# American Double / Imperial Stout         2
# American Pale Wheat Ale                  2
# American India Pale Lager                2
# American Barleywine                      2
# Belgian IPA                              2
# American Pale Lager                      2
# American White IPA                       2

# %%
#so here I checked what the most popular beers with an ibu in the lower 25%
low_ibu = low_ibu['style'].value_counts().to_frame().head(20)
low_ibu
# Out:
#                             style
# American Pale Wheat Ale        44
# American Blonde Ale            40
# Fruit / Vegetable Beer         29
# Witbier                        21
# Hefeweizen                     21
# American Amber / Red Ale       15
# Munich Helles Lager            11
# Kölsch                         11
# Cream Ale                      11
# American Adjunct Lager         11
# American Pale Lager             9
# American Brown Ale              8
# American Amber / Red Lager      7
# Gose                            7
# Saison / Farmhouse Ale          7
# Pumpkin Ale                     7
# American Pilsner                7
# English Brown Ale               6
# American Porter                 6
# Märzen / Oktoberfest            6

# %%
mid_ibu = beers[(beers['ibu']>21) & (beers['ibu']<=35)]

# %%
mid_ibu = mid_ibu['style'].value_counts().to_frame().head(20)
mid_ibu
# Out:
#                             style
# American Amber / Red Ale       36
# American Pale Ale (APA)        32
# American Porter                24
# American Brown Ale             21
# American Blonde Ale            18
# Kölsch                         16
# Saison / Farmhouse Ale         14
# Märzen / Oktoberfest           14
# American Pale Wheat Ale        13
# Czech Pilsener                 11
# Vienna Lager                   10
# Scotch Ale / Wee Heavy          8
# American Amber / Red Lager      7
# Scottish Ale                    7
# Cream Ale                       7
# American IPA                    7
# German Pilsener                 7
# Irish Red Ale                   6
# American Pilsner                6
# Hefeweizen                      5

# %%
ax = low_ibu.plot(kind='barh');
ax.set_title('LOW IBU');

# %%
ax2 = mid_ibu.plot(kind='barh')
ax2.set_title('MID IBU')
# Out:
# Text(0.5, 1.0, 'MID IBU')

# %%
ax = high.plot(kind='barh');
ax.set_title('HIGH IBU');

# %% [markdown]
# visualizing these I am wondering If I should get a drink's style and abv and guess bitterness, rather than guessing the style of beer.

# %%
tmp_ipa = beers[(beers['style']=='American IPA') & (beers['ibu']>=60) & (beers['ibu']<=75)]

# %%
tmp_ipa.describe()
# Out:
#         Unnamed: 0         abv         ibu           id  brewery_id  \
# count   170.000000  170.000000  170.000000   170.000000  170.000000
# mean   1173.735294    0.066553   67.541176  1451.294118  221.594118
# std     688.489063    0.005747    4.792877   730.644821  144.288235
# min      28.000000    0.043000   60.000000    10.000000    1.000000
# 25%     631.500000    0.062250   65.000000   796.250000   98.750000
# 50%    1154.000000    0.067000   69.000000  1549.500000  203.000000
# 75%    1834.750000    0.070000   70.000000  2048.500000  336.000000
# max    2399.000000    0.082000   75.000000  2675.000000  546.000000
#
#            ounces
# count  170.000000
# mean    13.548235
# std      2.533030
# min     12.000000
# 25%     12.000000
# 50%     12.000000
# 75%     16.000000
# max     32.000000

# %%
tmp_ipa['ibu'].plot(kind='bar',figsize=(15,8));

# %%
beers_test = beers[beers['style']== 'Cider']

# %%
beers_test.describe(percentiles=[.75,.25])
# Out:
#         Unnamed: 0        abv  ibu           id  brewery_id     ounces
# count    37.000000  37.000000  0.0    37.000000   37.000000  37.000000
# mean   1293.810811   0.060514  NaN  1592.702703  312.054054  14.270270
# std     834.079261   0.007981  NaN   451.970492  121.044975   2.008989
# min      15.000000   0.048000  NaN   822.000000   80.000000  12.000000
# 25%     596.000000   0.051000  NaN  1341.000000  185.000000  12.000000
# 50%    1317.000000   0.065000  NaN  1465.000000  338.000000  16.000000
# 75%    1985.000000   0.068000  NaN  1985.000000  416.000000  16.000000
# max    2392.000000   0.069000  NaN  2483.000000  501.000000  16.000000

# %%
x = beers_test['abv'].quantile([.25,.75])

# %%
y = x.to_frame()
y
# Out:
#         abv
# 0.25  0.051
# 0.75  0.068

# %%
beers['style'].value_counts()
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Kristalweizen                       1
# Smoked Beer                         1
# Flanders Oud Bruin                  1
# Flanders Red Ale                    1
# Braggot                             1
# Name: style, Length: 99, dtype: int64

# %%
beers[beers['style']== 'American Blonde Ale'].describe()
# Out:
#         Unnamed: 0         abv        ibu           id  brewery_id      ounces
# count   108.000000  104.000000  61.000000   108.000000  108.000000  108.000000
# mean   1107.231481    0.049635  20.983607  1320.527778  253.222222   13.185185
# std     622.822676    0.004941   7.281236   715.194287  152.427420    2.065055
# min      40.000000    0.035000   8.000000    44.000000   13.000000   12.000000
# 25%     639.750000    0.047000  17.000000   726.250000  126.000000   12.000000
# 50%    1042.500000    0.050000  20.000000  1288.000000  227.500000   12.000000
# 75%    1685.750000    0.052250  23.000000  1912.000000  385.250000   16.000000
# max    2378.000000    0.065000  50.000000  2632.000000  550.000000   24.000000

# %%
beers[beers['style']== 'American IPA'].describe()
# Out:
#         Unnamed: 0         abv         ibu           id  brewery_id  \
# count   424.000000  417.000000  301.000000   424.000000  424.000000
# mean   1209.360849    0.064528   67.634551  1484.117925  229.358491
# std     707.350381    0.008799   16.052601   742.697954  152.784305
# min       2.000000    0.027000   30.000000    10.000000    0.000000
# 25%     639.000000    0.061000   60.000000   880.500000   94.000000
# 50%    1164.000000    0.065000   69.000000  1593.000000  207.000000
# 75%    1846.500000    0.070000   75.000000  2090.750000  345.000000
# max    2399.000000    0.094000  135.000000  2692.000000  556.000000
#
#            ounces
# count  424.000000
# mean    13.581132
# std      2.415322
# min     12.000000
# 25%     12.000000
# 50%     12.000000
# 75%     16.000000
# max     32.000000

# %%
beers[beers['style']== 'American Pale Ale (APA)'].describe()
# Out:
#         Unnamed: 0         abv         ibu           id  brewery_id  \
# count   245.000000  239.000000  153.000000   245.000000  245.000000
# mean   1204.685714    0.054577   44.941176  1364.840816  244.424490
# std     675.190358    0.006322   11.542961   753.878069  155.401804
# min       1.000000    0.037000   16.000000     1.000000    1.000000
# 25%     658.000000    0.051000   36.000000   755.000000  124.000000
# 50%    1231.000000    0.055000   44.000000  1287.000000  192.000000
# 75%    1733.000000    0.058000   54.000000  1962.000000  372.000000
# max    2408.000000    0.073000   68.000000  2683.000000  556.000000
#
#            ounces
# count  245.000000
# mean    13.198367
# std      2.398496
# min     12.000000
# 25%     12.000000
# 50%     12.000000
# 75%     16.000000
# max     32.000000

# %%
beers[beers['style']== 'Hefeweizen'].describe()
# Out:
#         Unnamed: 0        abv        ibu           id  brewery_id     ounces
# count    40.000000  39.000000  27.000000    40.000000   40.000000  40.000000
# mean   1290.325000   0.051462  17.592593  1250.675000  290.175000  13.100000
# std     586.060703   0.005452   7.894785   801.577336  177.239355   2.394438
# min     204.000000   0.041000   8.000000    22.000000   30.000000  12.000000
# 25%     902.000000   0.049000  12.500000   511.000000  125.000000  12.000000
# 50%    1210.000000   0.050000  15.000000  1233.500000  294.000000  12.000000
# 75%    1706.250000   0.054500  18.000000  1836.250000  450.750000  12.000000
# max    2359.000000   0.070000  42.000000  2551.000000  556.000000  24.000000

# %%
beers[beers['style']== 'American Amber / Red Ale'].describe()
# Out:
#         Unnamed: 0         abv         ibu           id  brewery_id  \
# count   133.000000  125.000000   77.000000   133.000000  133.000000
# mean   1146.699248    0.057456   36.298701  1272.398496  248.045113
# std     656.251130    0.008679   19.630176   791.092129  158.265641
# min      41.000000    0.035000   15.000000    28.000000    4.000000
# 25%     572.000000    0.052000   24.000000   677.000000  101.000000
# 50%    1193.000000    0.055000   31.000000  1179.000000  219.000000
# 75%    1701.000000    0.060000   42.000000  1952.000000  375.000000
# max    2409.000000    0.082000  115.000000  2660.000000  552.000000
#
#            ounces
# count  133.000000
# mean    13.293233
# std      1.878031
# min     12.000000
# 25%     12.000000
# 50%     12.000000
# 75%     16.000000
# max     16.000000

# %%
beers[beers['style']== 'Cider']
# Out:
#       Unnamed: 0    abv  ibu    id                              name  style  \
# 15            15  0.060  NaN  2318                       Ginja Ninja  Cider
# 16            16  0.060  NaN  2170                     Cherried Away  Cider
# 17            17  0.060  NaN  2169                      Rhubarbarian  Cider
# 18            18  0.060  NaN  1502                       BrightCider  Cider
# 122          122  0.050  NaN  1294        Angry Orchard Apple Ginger  Cider
# 123          123  0.050  NaN  1293         Angry Orchard Crisp Apple  Cider
# 124          124  0.050  NaN  1292         Angry Orchard Crisp Apple  Cider
# 552          552  0.069  NaN  1465     Granny Smith Hard Apple Cider  Cider
# 553          553  0.069  NaN  1464              Dry Hard Apple Cider  Cider
# 596          596  0.050  NaN  1342                       First Press  Cider
# 597          597  0.050  NaN  1341                       Magic Apple  Cider
# ...

# %%
tmp_df = beers.dropna()

# %%
beers
# Out:
#       Unnamed: 0    abv   ibu    id                  name  \
# 0              0  0.050   NaN  1436              Pub Beer
# 1              1  0.066   NaN  2265           Devil's Cup
# 2              2  0.071   NaN  2264   Rise of the Phoenix
# 3              3  0.090   NaN  2263              Sinister
# 4              4  0.075   NaN  2262         Sex and Candy
# ...          ...    ...   ...   ...                   ...
# 2405        2405  0.067  45.0   928             Belgorado
# 2406        2406  0.052   NaN   807         Rail Yard Ale
# 2407        2407  0.055   NaN   620       B3K Black Lager
# 2408        2408  0.055  40.0   145   Silverback Pale Ale
# 2409        2409  0.052   NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces
# 0                American Pale Lager         408    12.0
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# ...

# %%
#this is a new df without beers without ibu
tmp_df
# Out:
#       Unnamed: 0    abv   ibu    id                                  name  \
# 14            14  0.061  60.0  1979                          Bitter Bitch
# 21            21  0.099  92.0  1036                         Lower De Boom
# 22            22  0.079  45.0  1024                         Fireside Chat
# 24            24  0.044  42.0   876                       Bitter American
# 25            25  0.049  17.0   802  Hell or High Watermelon Wheat (2009)
# ...          ...    ...   ...   ...                                   ...
# 2398        2398  0.077  30.0  1513  Lights Out Vanilla Cream Extra Stout
# 2399        2399  0.069  69.0  1512                     Worthy IPA (2013)
# 2400        2400  0.060  50.0  1511                           Worthy Pale
# 2405        2405  0.067  45.0   928                             Belgorado
# 2408        2408  0.055  40.0   145                   Silverback Pale Ale
#
#                                style  brewery_id  ounces
# ...

# %%
tmp_df['style'].value_counts()
# Out:
# American IPA                          301
# American Pale Ale (APA)               153
# American Amber / Red Ale               77
# American Double / Imperial IPA         75
# American Blonde Ale                    61
#                                      ...
# Grisette                                1
# American Double / Imperial Pilsner      1
# Belgian Strong Dark Ale                 1
# Flanders Oud Bruin                      1
# Euro Pale Lager                         1
# Name: style, Length: 90, dtype: int64

# %% [markdown]
# #### This is a lot of Exploratory and I have found that I may be able to drop the null values and it will make the list smaller and there will be a smaller number of different styles.
#
# #### In other words what I have seen that a lot of styles like 'Cider' and 'Gose' for example have zero entries with an ibu. So when I drop the null values there will be fewer unique styles of beer.
#
# #### That being said, with fewer possibilities I think it might be easier to predict style of beer by looking at ibu and abv.

# %% [markdown]
# #### I think my plan would be to look at styles of beer that have over a certain threshold of examples (25 maybe) and use those styles to train my model. Including a bunch of styles of beer that only have a few examples in my opinion is just a waste of time and will be very difficult for the model to predict
